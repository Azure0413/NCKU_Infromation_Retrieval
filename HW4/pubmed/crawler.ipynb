# %%
import os
import time
import requests
from xml.etree import ElementTree

def fetch_pubmed_xml(query, max_results=10, output_dir="output", batch_size=5, sleep_time=1):
    # Base URL for Entrez E-utilities
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/"

    # Step 1: Use ESearch to get the list of PubMed IDs (PMIDs) for the query
    search_url = f"{base_url}esearch.fcgi"
    search_params = {
        "db": "pubmed",
        "term": query,
        "retmax": max_results,
        "retmode": "xml"
    }

    search_response = requests.get(search_url, params=search_params)
    search_response.raise_for_status()
    search_xml = ElementTree.fromstring(search_response.content)

    # Extract PMIDs from the search results
    pmids = [id_elem.text for id_elem in search_xml.findall(".//Id")]

    if not pmids:
        print("No results found.")
        return

    # Ensure output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # Step 2: Fetch articles in batches to avoid rate limiting
    fetch_url = f"{base_url}efetch.fcgi"
    for i in range(0, len(pmids), batch_size):
        # Split PMIDs into batches
        batch_pmids = pmids[i:i + batch_size]
        fetch_params = {
            "db": "pubmed",
            "id": ",".join(batch_pmids),
            "retmode": "xml"
        }

        try:
            fetch_response = requests.get(fetch_url, params=fetch_params)
            fetch_response.raise_for_status()

            # Split fetched XML data and save each article by PMID
            articles = ElementTree.fromstring(fetch_response.content).findall(".//PubmedArticle")
            for article in articles:
                pmid = article.find(".//PMID").text
                file_path = os.path.join(output_dir, f"{pmid}.xml")

                with open(file_path, 'wb') as file:
                    file.write(ElementTree.tostring(article, encoding='utf-8'))

                print(f"Article {pmid} saved to {file_path}")

        except requests.exceptions.HTTPError as e:
            print(f"Failed to fetch batch {i+1} due to {e}")

        # Sleep to avoid hitting the rate limit
        time.sleep(sleep_time)

# Example usage:
query = "enterovirus"
max_results = 160  # Set the number of articles to download
output_directory = "data"  # Set your desired output directory
batch_size = 10  # Number of articles to fetch in each batch
sleep_time = 0.1  # Time in seconds to sleep between batches
fetch_pubmed_xml(query, max_results, output_directory, batch_size, sleep_time)
# Out:
# Article 39555929 saved to data\39555929.xml
# Article 39552883 saved to data\39552883.xml
# Article 39550578 saved to data\39550578.xml
# Article 39548776 saved to data\39548776.xml
# Article 39546098 saved to data\39546098.xml
# Article 39546035 saved to data\39546035.xml
# Article 39545343 saved to data\39545343.xml
# Article 39536108 saved to data\39536108.xml
# Article 39535185 saved to data\39535185.xml
# Article 39532602 saved to data\39532602.xml
# Article 39531817 saved to data\39531817.xml
# Article 39531247 saved to data\39531247.xml
# Article 39530331 saved to data\39530331.xml
# Article 39516037 saved to data\39516037.xml
# Article 39512378 saved to data\39512378.xml
# Article 39512164 saved to data\39512164.xml
# Article 39511383 saved to data\39511383.xml
# Article 39509266 saved to data\39509266.xml
# Article 39509140 saved to data\39509140.xml
# Article 39506010 saved to data\39506010.xml
# Article 39505825 saved to data\39505825.xml
# Article 39502449 saved to data\39502449.xml
# Article 39501367 saved to data\39501367.xml
# Article 39498233 saved to data\39498233.xml
# Article 39498118 saved to data\39498118.xml
# Article 39496810 saved to data\39496810.xml
# Article 39495348 saved to data\39495348.xml
# Article 39493374 saved to data\39493374.xml
# Article 39484685 saved to data\39484685.xml
# Article 39481292 saved to data\39481292.xml
# Article 39479873 saved to data\39479873.xml
# Article 39474447 saved to data\39474447.xml
# Article 39471505 saved to data\39471505.xml
# Article 39470428 saved to data\39470428.xml
# Article 39467726 saved to data\39467726.xml
# Article 39464754 saved to data\39464754.xml
# Article 39463956 saved to data\39463956.xml
# Article 39460332 saved to data\39460332.xml
# Article 39459875 saved to data\39459875.xml
# Article 39459854 saved to data\39459854.xml
# Article 39457005 saved to data\39457005.xml
# Article 39456264 saved to data\39456264.xml
# Article 39456193 saved to data\39456193.xml
# Article 39450473 saved to data\39450473.xml
# Article 39447148 saved to data\39447148.xml
# Article 39447143 saved to data\39447143.xml
# Article 39442312 saved to data\39442312.xml
# Article 39437765 saved to data\39437765.xml
# Article 39437532 saved to data\39437532.xml
# Article 39433164 saved to data\39433164.xml
# Article 39427898 saved to data\39427898.xml
# Article 39424982 saved to data\39424982.xml
# Article 39422471 saved to data\39422471.xml
# Article 39422382 saved to data\39422382.xml
# Article 39420189 saved to data\39420189.xml
# Article 39419452 saved to data\39419452.xml
# Article 39418957 saved to data\39418957.xml
# Article 39418214 saved to data\39418214.xml
# Article 39411664 saved to data\39411664.xml
# Article 39408741 saved to data\39408741.xml
# Article 39405931 saved to data\39405931.xml
# Article 39402977 saved to data\39402977.xml
# Article 39402647 saved to data\39402647.xml
# Article 39399533 saved to data\39399533.xml
# Article 39399343 saved to data\39399343.xml
# Article 39387429 saved to data\39387429.xml
# Article 39394962 saved to data\39394962.xml
# Article 39392025 saved to data\39392025.xml
# Article 39392006 saved to data\39392006.xml
# Article 39373578 saved to data\39373578.xml
# Article 39370858 saved to data\39370858.xml
# Article 39369233 saved to data\39369233.xml
# Article 39368548 saved to data\39368548.xml
# Article 39367210 saved to data\39367210.xml
# Article 39365457 saved to data\39365457.xml
# Article 39365047 saved to data\39365047.xml
# Article 39364390 saved to data\39364390.xml
# Article 39357254 saved to data\39357254.xml
# Article 39355427 saved to data\39355427.xml
# Article 39351302 saved to data\39351302.xml
# Article 39350170 saved to data\39350170.xml
# Article 39348396 saved to data\39348396.xml
# Article 39345463 saved to data\39345463.xml
# Article 39345228 saved to data\39345228.xml
# Article 39343096 saved to data\39343096.xml
# Article 39342950 saved to data\39342950.xml
# Article 39340058 saved to data\39340058.xml
# Article 39340018 saved to data\39340018.xml
# Article 39339994 saved to data\39339994.xml
# Article 39339978 saved to data\39339978.xml
# Article 39339932 saved to data\39339932.xml
# Article 39339923 saved to data\39339923.xml
# Article 39339895 saved to data\39339895.xml
# Article 39339856 saved to data\39339856.xml
# Article 39339854 saved to data\39339854.xml
# Article 39338968 saved to data\39338968.xml
# Article 39338380 saved to data\39338380.xml
# Article 39338252 saved to data\39338252.xml
# Article 39335111 saved to data\39335111.xml
# Article 39332429 saved to data\39332429.xml
# Article 39329140 saved to data\39329140.xml
# Article 39324793 saved to data\39324793.xml
# Article 39322496 saved to data\39322496.xml
# Article 39315747 saved to data\39315747.xml
# Article 39314969 saved to data\39314969.xml
# Article 39313857 saved to data\39313857.xml
# Article 39312587 saved to data\39312587.xml
# Article 39311842 saved to data\39311842.xml
# Article 39311627 saved to data\39311627.xml
# Article 39311394 saved to data\39311394.xml
# Article 39306193 saved to data\39306193.xml
# Article 39300570 saved to data\39300570.xml
# Article 39298881 saved to data\39298881.xml
# Article 39298524 saved to data\39298524.xml
# Article 39295283 saved to data\39295283.xml
# Article 39292620 saved to data\39292620.xml
# Article 39287389 saved to data\39287389.xml
# Article 39284332 saved to data\39284332.xml
# Article 39282406 saved to data\39282406.xml
# Article 39280569 saved to data\39280569.xml
# Article 39273613 saved to data\39273613.xml
# Article 39273444 saved to data\39273444.xml
# Article 39272111 saved to data\39272111.xml
# Article 39270846 saved to data\39270846.xml
# Article 39267792 saved to data\39267792.xml
# Article 39265768 saved to data\39265768.xml
# Article 39264848 saved to data\39264848.xml
# Article 39261649 saved to data\39261649.xml
# Article 39261375 saved to data\39261375.xml
# Article 39258623 saved to data\39258623.xml
# Article 39257116 saved to data\39257116.xml
# Article 39254312 saved to data\39254312.xml
# Article 39252862 saved to data\39252862.xml
# Article 39251138 saved to data\39251138.xml
# Article 39246649 saved to data\39246649.xml
# Article 39245513 saved to data\39245513.xml
# Article 39243991 saved to data\39243991.xml
# Article 39239635 saved to data\39239635.xml
# Article 39236986 saved to data\39236986.xml
# Article 39235279 saved to data\39235279.xml
# Article 39234544 saved to data\39234544.xml
# Article 39230517 saved to data\39230517.xml
# Article 39229797 saved to data\39229797.xml
# Article 39228900 saved to data\39228900.xml
# Article 39227731 saved to data\39227731.xml
# Article 39226680 saved to data\39226680.xml
# Article 39224868 saved to data\39224868.xml
# Article 39223319 saved to data\39223319.xml
# Article 39220203 saved to data\39220203.xml
# Article 39218378 saved to data\39218378.xml
# Article 39217989 saved to data\39217989.xml
# Article 39216881 saved to data\39216881.xml
# Article 39216128 saved to data\39216128.xml
# Article 39215587 saved to data\39215587.xml
# Article 39214397 saved to data\39214397.xml
# Article 39213902 saved to data\39213902.xml
# Article 39212385 saved to data\39212385.xml
# Article 39207089 saved to data\39207089.xml
# Article 39205263 saved to data\39205263.xml
